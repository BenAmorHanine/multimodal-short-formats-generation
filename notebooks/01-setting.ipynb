# %%
# %pip install torch torchvision torchaudio
# %pip install transformers accelerate
# %pip install jupyter notebook ipykernel
# %pip install numpy scipy scikit-learn matplotlib tqdm
# Out:
# Requirement already satisfied: torch in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (2.10.0)
# Requirement already satisfied: torchvision in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (0.25.0)
# Requirement already satisfied: torchaudio in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (2.10.0)
# Requirement already satisfied: filelock in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from torch) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from torch) (2026.2.0)
# Requirement already satisfied: setuptools in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from torch) (81.0.0)
# Requirement already satisfied: numpy in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from torchvision) (2.3.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from torchvision) (12.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jinja2->torch) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: transformers in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (5.1.0)
# Requirement already satisfied: accelerate in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (1.12.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from transformers) (1.4.1)
# Requirement already satisfied: numpy>=1.17 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from transformers) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from transformers) (2026.1.15)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer-slim in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from transformers) (4.67.3)
# Requirement already satisfied: psutil in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from accelerate) (7.2.2)
# Requirement already satisfied: torch>=2.0.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from accelerate) (2.10.0)
# Requirement already satisfied: filelock in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Requirement already satisfied: shellingham in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.5.4)
# Requirement already satisfied: typing-extensions>=4.1.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from torch>=2.0.0->accelerate) (3.6.1)
# Requirement already satisfied: jinja2 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: setuptools in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from torch>=2.0.0->accelerate) (81.0.0)
# Requirement already satisfied: colorama in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from typer-slim->transformers) (8.3.1)
# Requirement already satisfied: anyio in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: idna in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: jupyter in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (1.1.1)
# Requirement already satisfied: notebook in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (7.5.3)
# Requirement already satisfied: ipykernel in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (7.2.0)
# Requirement already satisfied: jupyter-console in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jupyter) (7.17.0)
# Requirement already satisfied: ipywidgets in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jupyter) (8.1.8)
# Requirement already satisfied: jupyterlab in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jupyter) (4.5.3)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from notebook) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from notebook) (2.28.0)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from notebook) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from notebook) (6.5.4)
# Requirement already satisfied: comm>=0.1.1 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from ipykernel) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from ipykernel) (9.10.0)
# Requirement already satisfied: jupyter-client>=8.8.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from ipykernel) (8.8.0)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from ipykernel) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging>=22 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from ipykernel) (26.0)
# Requirement already satisfied: psutil>=5.7 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from ipykernel) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: traitlets>=5.4.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: colorama>=0.4.4 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jupyter-client>=8.8.0->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel) (4.5.1)
# Requirement already satisfied: anyio>=3.1.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (4.12.1)
# Requirement already satisfied: argon2-cffi>=21.1 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (25.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.1.6)
# Requirement already satisfied: jupyter-events>=0.11.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.5.4)
# Requirement already satisfied: nbformat>=5.3.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.24.1)
# Requirement already satisfied: pywinpty>=2.0.1 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.0.3)
# Requirement already satisfied: send2trash>=1.8.2 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.9.0)
# Requirement already satisfied: async-lru>=1.0.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jupyterlab->jupyter) (2.1.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jupyterlab->jupyter) (2.3.0)
# Requirement already satisfied: setuptools>=41.1.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jupyterlab->jupyter) (81.0.0)
# Requirement already satisfied: babel>=2.10 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (0.13.0)
# Requirement already satisfied: jsonschema>=4.18.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (4.26.0)
# Requirement already satisfied: requests>=2.31 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (2.32.5)
# Requirement already satisfied: beautifulsoup4 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from nbconvert->jupyter) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.3.0)
# Requirement already satisfied: defusedxml in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from nbconvert->jupyter) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from nbconvert->jupyter) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from nbconvert->jupyter) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from ipywidgets->jupyter) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from ipywidgets->jupyter) (3.0.16)
# Requirement already satisfied: idna>=2.8 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (3.11)
# Requirement already satisfied: typing_extensions>=4.5 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (4.15.0)
# Requirement already satisfied: argon2-cffi-bindings in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (25.1.0)
# Requirement already satisfied: webencodings in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: certifi in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (1.0.9)
# Requirement already satisfied: h11>=0.16 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter) (0.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel) (0.8.5)
# Requirement already satisfied: attrs>=22.2.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (0.30.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (6.0.3)
# Requirement already satisfied: rfc3339-validator in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (0.1.1)
# Requirement already satisfied: fastjsonschema>=2.15 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook) (2.21.2)
# Requirement already satisfied: wcwidth in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.6.0)
# Requirement already satisfied: six>=1.5 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.8.0->ipykernel) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->notebook) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->notebook) (2.6.3)
# Requirement already satisfied: executing>=1.2.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (3.0.1)
# Requirement already satisfied: pure-eval in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (0.2.3)
# Requirement already satisfied: soupsieve>=1.6.1 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.8.3)
# Requirement already satisfied: fqdn in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: isoduration in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.1.0)
# Requirement already satisfied: uri-template in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (25.10.0)
# Requirement already satisfied: cffi>=1.0.1 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (2.0.0)
# Requirement already satisfied: pycparser in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (3.0)
# Requirement already satisfied: lark>=1.2.2 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.4.0)
# Requirement already satisfied: tzdata in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (2025.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (2.3.5)
# Requirement already satisfied: scipy in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (1.17.0)
# Requirement already satisfied: scikit-learn in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (1.8.0)
# Requirement already satisfied: matplotlib in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (3.10.8)
# Requirement already satisfied: tqdm in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (4.67.3)
# Requirement already satisfied: joblib>=1.3.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: colorama in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: six>=1.5 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install librosa decord opencv-python
# Out:
# Requirement already satisfied: librosa in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (0.11.0)
# Requirement already satisfied: decord in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (0.6.0)
# Requirement already satisfied: opencv-python in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (4.13.0.92)
# Requirement already satisfied: audioread>=2.1.9 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from librosa) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from librosa) (0.63.1)
# Requirement already satisfied: numpy>=1.22.3 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from librosa) (2.3.5)
# Requirement already satisfied: scipy>=1.6.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from librosa) (1.17.0)
# Requirement already satisfied: scikit-learn>=1.1.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from librosa) (1.8.0)
# Requirement already satisfied: joblib>=1.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from librosa) (1.5.3)
# Requirement already satisfied: decorator>=4.3.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from librosa) (5.2.1)
# Requirement already satisfied: soundfile>=0.12.1 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from librosa) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from librosa) (1.9.0)
# Requirement already satisfied: soxr>=0.3.2 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from librosa) (1.0.0)
# Requirement already satisfied: typing_extensions>=4.1.1 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from librosa) (4.15.0)
# Requirement already satisfied: lazy_loader>=0.1 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from librosa) (1.1.2)
# Requirement already satisfied: packaging in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from lazy_loader>=0.1->librosa) (26.0)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from numba>=0.51.0->librosa) (0.46.0)
# Requirement already satisfied: platformdirs>=2.5.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from pooch>=1.1->librosa) (4.5.1)
# Requirement already satisfied: requests>=2.19.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from pooch>=1.1->librosa) (2.32.5)
# Requirement already satisfied: threadpoolctl>=3.2.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from scikit-learn>=1.1.0->librosa) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from soundfile>=0.12.1->librosa) (2.0.0)
# Requirement already satisfied: pycparser in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in e:\pfa--multimodal-short-formats-generation\shorts-venv\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2026.1.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
