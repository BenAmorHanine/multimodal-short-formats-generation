# %%
# !pip install -q gradio

# %% [markdown]
# why gradio?
#
#
# bcz it is the state of the art to  integrate ml models into web applications
#
# the script is also in the drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append("/content/drive/MyDrive/PFA")

# %%
from scriptss.interface import launch_interface

launch_interface()
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://1eee4f17aa04d087d0.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://1eee4f17aa04d087d0.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
